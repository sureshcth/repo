# %%
from pylab import *
a = 10.0
for a in range(5,21,5):
	th = linspace(0, pi * a/10, 2000) 
	x = a * cos(th)
	y = a * sin(th)
	plot(x,y)
show()

# %%
from pylab import *
k=4
th = linspace(0, 10*pi,1000) 
r = cos(k*th)
polar(th,r)
show()

# %%
th
# Out:
# array([  0.00000000e+00,   3.14316424e-03,   6.28632847e-03, ...,
#          6.27689898e+00,   6.28004214e+00,   6.28318531e+00])
